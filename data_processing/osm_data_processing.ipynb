# %%
import pandas as pd

# %%
df = pd.read_csv('~/mission_sih/mission_sih/data/osm_data.csv')
# Out:
# /tmp/ipykernel_8747/1983769110.py:1: DtypeWarning: Columns (0: industrial, 1: power, 2: plant_source, 3: man_made, 4: volcano_status, 5: volcano_type, 6: operator, 7: utility) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('~/mission_sih/mission_sih/data/osm_data.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 67115 entries, 0 to 67114
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   osm_id          67115 non-null  int64
#  1   osm_type        67115 non-null  str
#  2   latitude        67115 non-null  float64
#  3   longitude       67115 non-null  float64
#  4   name            14931 non-null  str
#  5   osm_category    67115 non-null  str
#  6   industrial      8962 non-null   str
#  7   landuse         51533 non-null  str
#  8   power           7245 non-null   str
#  9   plant_source    6951 non-null   str
#  10  man_made        10787 non-null  str
#  11  natural         103 non-null    str
#  12  geological      0 non-null      float64
#  13  volcano_status  10 non-null     str
#  14  volcano_type    34 non-null     str
#  15  operator        2224 non-null   str
#  16  resource        5603 non-null   str
#  17  product         2092 non-null   str
# ...

# %%
df.head(3)
# Out:
#        osm_id osm_type   latitude  longitude               name osm_category  \
# 0  9724508685     node  27.649012  85.279633  Everest gas house    gas_flare
# 1  2681971011     node  36.380899  94.956140                NaN    gas_flare
# 2  3167049316     node  36.386108  94.962024                NaN    gas_flare
#
#   industrial landuse power plant_source man_made natural  geological  \
# 0        NaN     NaN   NaN          NaN    flare     NaN         NaN
# 1        NaN     NaN   NaN          NaN    flare     NaN         NaN
# 2        NaN     NaN   NaN          NaN    flare     NaN         NaN
#
#   volcano_status volcano_type operator resource product utility wikidata  \
# 0            NaN          NaN      NaN      NaN     NaN     NaN      NaN
# 1            NaN          NaN      NaN      NaN     NaN     NaN      NaN
# 2            NaN          NaN      NaN      NaN     NaN     NaN      NaN
#
#                                             raw_tags
# ...

# %%
pd.unique(df["osm_category"])
# Out:
# <StringArray>
# [          'gas_flare', 'industrial_facility',                'mine',
#              'oil_gas',         'power_plant',              'quarry',
#              'volcano']
# Length: 7, dtype: str

# %%
df2 = df[df["osm_category"] != "volcano"]

# %%
df2.drop(columns=["osm_id","osm_type","name","industrial","landuse","power","plant_source","man_made","natural","geological","volcano_status","volcano_type","operator","resource","product","utility","wikidata","raw_tags"], inplace=True)

# %%
pd.unique(df2["osm_category"])
# Out:
# <StringArray>
# ['gas_flare', 'industrial_facility', 'mine', 'oil_gas', 'power_plant',
#  'quarry']
# Length: 6, dtype: str
